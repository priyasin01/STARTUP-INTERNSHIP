# %%
import numpy as np
import pandas as pd

# %%
path="all_delhi_database.xlsx"
df=pd.read_excel(path)

# %%
df.head()
# Out:
#                          Name                     Email Id     Mobile No.  \
# 0                      Gautam        gautam.4537@gmail.com  91-9958429337
# 1  A B ASRAFUL HAQUEBARBHUIYA           ab_luies1@yahoo.in  91-9716433202
# 2                     A DAVID         ak_david23@yahoo.com  91-9711259279
# 3               A GautamKumar  agautamkumar@indiatimes.com  91-9211299778
# 4               A GSIVASANKAR     sivasankar1323@gmail.com  91-9717959337
#
#            Unnamed: 3
# 0     Shivaji College
# 1       Hindu College
# 2                 CVS
# 3   Ramanujan College
# 4  Deshbandhu College

# %% [markdown]
# Given above are the first 5 rows of our Dataset.(Sample data)

# %%
df.columns=["Name","Email_Id","Mobile_No.","College"]

# %% [markdown]
# Since, the headers in our dataset aren't correct so we will change the headers as part of preprocessing of our dataset for analysis.

# %%
df.head()
# Out:
#                          Name                     Email_Id     Mobile_No.  \
# 0                      Gautam        gautam.4537@gmail.com  91-9958429337
# 1  A B ASRAFUL HAQUEBARBHUIYA           ab_luies1@yahoo.in  91-9716433202
# 2                     A DAVID         ak_david23@yahoo.com  91-9711259279
# 3               A GautamKumar  agautamkumar@indiatimes.com  91-9211299778
# 4               A GSIVASANKAR     sivasankar1323@gmail.com  91-9717959337
#
#               College
# 0     Shivaji College
# 1       Hindu College
# 2                 CVS
# 3   Ramanujan College
# 4  Deshbandhu College

# %% [markdown]
# Dataset(first 5 rows) after adding headers.

# %%
df.tail()
# Out:
#                  Name                 Email_Id     Mobile_No.  \
# 65528    zuhaibusmani  zuhaib.usmani@gmail.com  91-9911688992
# 65529    ZUHAIRREHMAN     z_rehman@hotmail.com  91-9717110057
# 65530    ZuhairTorabi    zuhairflahi@gmail.com  91-9873323980
# 65531  zulfequar khan    zulfequar84@gmail.com  91-9268755652
# 65532   ZulfiqarAhmad    zulfiindian@gmail.com  91-9899961748
#
#                         College  Total
# 65528             Hindu College  65533
# 65529               SGTB Khalsa  65533
# 65530          Rajdhani College  65533
# 65531  maharaja agrasen college  65533
# 65532          Rajdhani College  65533

# %% [markdown]
# Given above are the last five rows of our dataset.

# %%
df.columns
# Out:
# Index(['Name', 'Email_Id', 'Mobile_No.', 'College', 'Total'], dtype='object')

# %% [markdown]
# Given above are the main features in our dataset.

# %%
df.dtypes
# Out:
# Name          object
# Email_Id      object
# Mobile_No.    object
# College       object
# Total          int64
# dtype: object

# %%
df.describe(include = "all")
# Out:
#              Name                   Email_Id  Mobile_No. College
# count       65532                      65475       65533   65533
# unique      50479                      65058       65526      25
# top     AmitKumar  ajay_kanojiya23@yahoo.com   991108911     CVS
# freq           74                          3           2    6168

# %% [markdown]
# We can see the some statistics about our complete dataset in the dataframe given above. We see that there are some missing values as the total count of different columns are different. One student has not provided his/her name and around 58 students have not provided their email addresses.
# In name column we have 50479 unique values, some people might be having same names. In email Id column we have 65058 unique mail ids. This means some students have used their friend's email id. Similarly we have 65526 unique mobile nos , that means around 8 students have used their friend's mobile number.
# We see that there are 25 unique colleges from where we had our students.
# The top field shows the most occuring entity. So we can see that Amit Kumar is the most occuring name, ajay_kanojiya23@yahoo.com was used the most number of times. 991108911 is the mobile no. used by most number of students. And we had maximum students from CVS college.

# %%
df.info
# Out:
# <bound method DataFrame.info of                              Name                         Email_Id  \
# 0                          Gautam            gautam.4537@gmail.com
# 1      A B ASRAFUL HAQUEBARBHUIYA               ab_luies1@yahoo.in
# 2                         A DAVID             ak_david23@yahoo.com
# 3                   A GautamKumar      agautamkumar@indiatimes.com
# 4                   A GSIVASANKAR         sivasankar1323@gmail.com
# 5                   A KARTIKKUMAR      kartiksubha_chanu@yahoo.com
# 6                   A KSrivastava                  aksri@ymail.com
# 7                           divij             dvp.saxena@gmail.com
# 8                         vishwas                  vish1@yahoo.com
# 9              aadarsh kumarsingh     aadarshkumar.singh@gmail.com
# 10            AADESH KUMAR SHARMA        aadesh_tax@rediffmail.com
# 11                 aadeshbhardwaj             abhbd@rediffmail.com
# ...

# %%
df.size
# Out:
# 262132

# %%
df.shape
# Out:
# (65533, 4)

# %% [markdown]
# Total number of entities in our dataset are 65533.

# %%
df['College'].value_counts()
# Out:
# CVS                                   6168
# Veenkateswara College                 5602
# moti lal nehru college                5222
# SGTB Khalsa                           4656
# Deshbandhu College                    4562
# Hansraj College                       4118
# Shivaji College                       4050
# Ramjas College                        3270
# college of vocational studies         3094
# Ramanujan College                     2826
# Rajdhani College                      2772
# Hindu College                         2469
# kirorimal college                     2428
# atma ram sanatam dharam college       2383
# st. Stephens                          2048
# SRCC                                  1772
# Delhi college of arts and commerce    1377
# Shaheed Sukdhev                       1352
# Guru Gobind Singh                     1290
# maharaja agrasen college              1156
# hansraj college                       1011
# shaheed bhagat singh                   706
# ...

# %% [markdown]
# The above statistic shows the total number of students from each of the 25 colleges. We had the maximum number of students from CVS and the least number of students from Keshav Mahavidyalaya.

# %%
# use the inline backend to generate the plots within the browser
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.
# Out:
# Matplotlib version:  3.0.0

# %%
df['College'].value_counts().plot(kind='bar')

# %% [markdown]
# Final some visual representation of our students from different colleges.

# %%
df['College'].value_counts().plot(kind='pie',figsize=(24, 28),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,    )   # add shadow

# %% [markdown]
# Pie chart of the number of students according to college.
